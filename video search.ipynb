# %%
pip install streamlit_jupyter
# Out:
# ...
#   Using cached bleach-6.2.0-py3-none-any.whl.metadata (30 kB)
# ...
#   Using cached defusedxml-0.7.1-py2.py3-none-any.whl.metadata (32 kB)
# ...
#   Using cached babel-2.17.0-py3-none-any.whl.metadata (2.0 kB)
# ...
#   Using cached fastjsonschema-2.21.1-py3-none-any.whl.metadata (2.2 kB)
# ...
#   Using cached argon2_cffi_bindings-21.2.0-cp38-abi3-macosx_10_9_universal2.whl.metadata (6.7 kB)
# ...
#   Using cached fqdn-1.5.1-py3-none-any.whl.metadata (1.4 kB)
# ...
#   Using cached arrow-1.3.0-py3-none-any.whl.metadata (7.5 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 3.0 MB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.3/14.3 MB 8.9 MB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.3/12.3 MB 10.9 MB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.2/10.2 MB 11.4 MB/s eta 0:00:00 0:00:01
# ...
#
# [notice] A new release of pip is available: 24.2 -> 25.1.1
# [notice] To update, run: pip install --upgrade pip
# ...

# %%
import streamlit as st

# %%
st.write("Video search engine")
# Out:
# 2025-06-22 15:06:37.174 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-22 15:06:37.201
# ...
#   command:
#
#     streamlit run /Users/saurabhpathak/.pyenv/versions/3.13.0/lib/python3.13/site-packages/ipykernel_launcher.py [ARGUMENTS]
# 2025-06-22 15:06:37.201 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-22 15:06:37.201 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
